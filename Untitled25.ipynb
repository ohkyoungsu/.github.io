# %%
import numpy as np
import pandas as pd
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
from tqdm import tqdm, trange

# %%
import pickle

# %%
train_df = pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/train_data_df.csv') #Set Dir
test_df = pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/test_data_df.csv') #Set Dir

# %%
import ast
train_df['token'] = train_df['token'].apply(ast.literal_eval)
train_df['token_tag'] = train_df['token_tag'].apply(ast.literal_eval)
test_df['token'] = test_df['token'].apply(ast.literal_eval)
test_df['token_tag'] = test_df['token_tag'].apply(ast.literal_eval)

train_words = train_df.token
train_tags = train_df.token_tag

test_words = test_df.token
test_tags = test_df.token_tag

# %%
train_df.head()
# Out:
#    Unnamed: 0                                              token  \
# 0           0  [admission, date:, discharge, date:, date, of,...
# 1           1  [admission, date:, discharge, date:, date, of,...
# 2           2  [admission, date:, discharge, date:, date, of,...
# 3           3  [admission, date:, discharge, date:, date, of,...
# 4           4  [admission, date:, discharge, date:, date, of,...
#
#                                            token_tag
# 0  [O, O, O, O, O, O, O, O, O, O, O, O, B-Drug, O...
# 1  [O, O, O, O, O, O, O, O, O, O, O, O, B-Drug, O...
# 2  [O, O, O, O, O, O, O, O, O, O, O, O, B-Drug, O...
# 3  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 4  [O, O, O, O, O, O, O, O, O, O, O, O, B-Drug, O...

# %%
# !pip install numpy requests nlpaug
# Out:
# ...
#      |████████████████████████████████| 410 kB 5.3 MB/s
# ...

# %%
# !pip install torch>=1.6.0 transformers>=4.0.0 sentencepiece
# !pip install nltk

# %%
from nlpaug.util.file.download import DownloadUtil

# download word2vec
DownloadUtil.download_word2vec(dest_dir='.')
DownloadUtil.download_glove(model_name='glove.6B', dest_dir='.')

# download fasttext model
DownloadUtil.download_fasttext(model_name='wiki-news-300d-1M', dest_dir='.')

# %%
import nlpaug.augmenter.word as naw
import nlpaug.flow as nafc
from nlpaug.util import Action
from tqdm import tqdm

# %%
# !pip install transformers

# %%
aug = naw.ContextualWordEmbsAug(model_path='bert-base-uncased', action="insert")
# Out:
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/455k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/420M [00:00<?, ?B/s]

# %%
argu_list = []

# %%
for i in range(len(train_df.token)):
  temp = ''
  for j in train_df.token.iloc[i]:
    temp += j
    temp += ' '
  augmented_text = aug.augment(temp)
  argu_list.append(augmented_text)

# %%
argu_token = []

# %%
for i in range(len(argu_list)):
  argu_token.append([])

# %%
for i in range(len(argu_list)):
  argu_token[i].append(argu_list[i].split())

# %%
len(argu_token[0][0])
# Out:
# 3295

# %%
len(train_df.token.iloc[0])
# Out:
# 2741

# %%
argu_tag = []

# %%
temp_i = 0

# %%
for j in range(len(train_df.token)):
  temp_i = 0
  argu_tag.append([])
  for i in range(len(train_df.token.iloc[j])):
    try:
      if train_df.token.iloc[j][i] == argu_token[j][0][temp_i]:
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        temp_i += 1
      elif train_df.token.iloc[j][i] == (argu_token[j][0][temp_i] + argu_token[j][0][temp_i + 1]):
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        temp_i += 2
      elif train_df.token.iloc[j][i] == (argu_token[j][0][temp_i] + argu_token[j][0][temp_i + 1] + argu_token[j][0][temp_i + 2]):
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        temp_i += 3
      elif train_df.token.iloc[j][i] == (argu_token[j][0][temp_i] + argu_token[j][0][temp_i + 1] + argu_token[j][0][temp_i + 2] + argu_token[j][0][temp_i + 3]):
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        temp_i += 4
      elif train_df.token.iloc[j][i] == (argu_token[j][0][temp_i] + argu_token[j][0][temp_i + 1] + argu_token[j][0][temp_i + 2] + argu_token[j][0][temp_i + 3] + argu_token[j][0][temp_i + 4]):
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        temp_i += 5
      elif train_df.token.iloc[j][i] == (argu_token[j][0][temp_i] + argu_token[j][0][temp_i + 1] + argu_token[j][0][temp_i + 2] + argu_token[j][0][temp_i + 3] + argu_token[j][0][temp_i + 4] + argu_token[j][0][temp_i + 5]):
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        temp_i += 6
      elif train_df.token.iloc[j][i] == (argu_token[j][0][temp_i] + argu_token[j][0][temp_i + 1] + argu_token[j][0][temp_i + 2] + argu_token[j][0][temp_i + 3] + argu_token[j][0][temp_i + 4]  + argu_token[j][0][temp_i + 5] + argu_token[j][0][temp_i + 6]):
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        temp_i += 7
      elif train_df.token.iloc[j][i] == (argu_token[j][0][temp_i] + argu_token[j][0][temp_i + 1] + argu_token[j][0][temp_i + 2] + argu_token[j][0][temp_i + 3] + argu_token[j][0][temp_i + 4]  + argu_token[j][0][temp_i + 5] + argu_token[j][0][temp_i + 6] + argu_token[j][0][temp_i + 7]):
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        temp_i += 8
      elif train_df.token.iloc[j][i] == (argu_token[j][0][temp_i] + argu_token[j][0][temp_i + 1] + argu_token[j][0][temp_i + 2] + argu_token[j][0][temp_i + 3] + argu_token[j][0][temp_i + 4]  + argu_token[j][0][temp_i + 5] + argu_token[j][0][temp_i + 6] + argu_token[j][0][temp_i + 7] + argu_token[j][0][temp_i + 8]):
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        temp_i += 9
      elif train_df.token.iloc[j][i] == (argu_token[j][0][temp_i] + argu_token[j][0][temp_i + 1] + argu_token[j][0][temp_i + 2] + argu_token[j][0][temp_i + 3] + argu_token[j][0][temp_i + 4]  + argu_token[j][0][temp_i + 5] + argu_token[j][0][temp_i + 6] + argu_token[j][0][temp_i + 7] + argu_token[j][0][temp_i + 8] + argu_token[j][0][temp_i + 9]):
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        temp_i += 10
      elif train_df.token.iloc[j][i] == (argu_token[j][0][temp_i] + argu_token[j][0][temp_i + 1] + argu_token[j][0][temp_i + 2] + argu_token[j][0][temp_i + 3] + argu_token[j][0][temp_i + 4]  + argu_token[j][0][temp_i + 5] + argu_token[j][0][temp_i + 6] + argu_token[j][0][temp_i + 7] + argu_token[j][0][temp_i + 8] + argu_token[j][0][temp_i + 9] + argu_token[j][0][temp_i + 10]):
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])

        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        temp_i += 10
      elif train_df.token.iloc[j][i] == (argu_token[j][0][temp_i] + argu_token[j][0][temp_i + 1] + argu_token[j][0][temp_i + 2] + argu_token[j][0][temp_i + 3] + argu_token[j][0][temp_i + 4]  + argu_token[j][0][temp_i + 5] + argu_token[j][0][temp_i + 6] + argu_token[j][0][temp_i + 7] + argu_token[j][0][temp_i + 8] + argu_token[j][0][temp_i + 9] + argu_token[j][0][temp_i + 10] + argu_token[j][0][temp_i + 11]):
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])

        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])

        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        temp_i += 11
      elif train_df.token.iloc[j][i] == (argu_token[j][0][temp_i] + argu_token[j][0][temp_i + 1] + argu_token[j][0][temp_i + 2] + argu_token[j][0][temp_i + 3] + argu_token[j][0][temp_i + 4]  + argu_token[j][0][temp_i + 5] + argu_token[j][0][temp_i + 6] + argu_token[j][0][temp_i + 7] + argu_token[j][0][temp_i + 8] + argu_token[j][0][temp_i + 9] + argu_token[j][0][temp_i + 10] + argu_token[j][0][temp_i + 11] + argu_token[j][0][temp_i + 12]):
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])

        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])

        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        temp_i += 12
      elif train_df.token.iloc[j][i] == (argu_token[j][0][temp_i] + argu_token[j][0][temp_i + 1] + argu_token[j][0][temp_i + 2] + argu_token[j][0][temp_i + 3] + argu_token[j][0][temp_i + 4]  + argu_token[j][0][temp_i + 5] + argu_token[j][0][temp_i + 6] + argu_token[j][0][temp_i + 7] + argu_token[j][0][temp_i + 8] + argu_token[j][0][temp_i + 9] + argu_token[j][0][temp_i + 10] + argu_token[j][0][temp_i + 11] + argu_token[j][0][temp_i + 12] + argu_token[j][0][temp_i + 13]):
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])

        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])

        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        temp_i += 13
      elif train_df.token.iloc[j][i] == (argu_token[j][0][temp_i] + argu_token[j][0][temp_i + 1] + argu_token[j][0][temp_i + 2] + argu_token[j][0][temp_i + 3] + argu_token[j][0][temp_i + 4]  + argu_token[j][0][temp_i + 5] + argu_token[j][0][temp_i + 6] + argu_token[j][0][temp_i + 7] + argu_token[j][0][temp_i + 8] + argu_token[j][0][temp_i + 9] + argu_token[j][0][temp_i + 10] + argu_token[j][0][temp_i + 11] + argu_token[j][0][temp_i + 12] + argu_token[j][0][temp_i + 13] + argu_token[j][0][temp_i + 14]):
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])

        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])

        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        temp_i += 14
      else:
        if (train_df.token.iloc[j][i] + train_df.token.iloc[j][i+1]) == argu_token[j][0][temp_i]:
          continue

        if train_df.token.iloc[j][i] == argu_token[j][0][temp_i+1]:
          argu_tag[j].append("O")
          argu_tag[j].append(train_df.token_tag.iloc[j][i])
          temp_i += 2
        elif train_df.token.iloc[j][i] == argu_token[j][0][temp_i + 2]:
          argu_tag[j].append("O")
          argu_tag[j].append("O")
          argu_tag[j].append(train_df.token_tag.iloc[j][i])
          temp_i += 3
        elif train_df.token.iloc[j][i] == argu_token[j][0][temp_i + 3]:
          argu_tag[j].append("O")
          argu_tag[j].append("O")
          argu_tag[j].append("O")
          argu_tag[j].append(train_df.token_tag.iloc[j][i])
          temp_i += 4
        elif train_df.token.iloc[j][i] == argu_token[j][0][temp_i + 4]:
          argu_tag[j].append("O")
          argu_tag[j].append("O")
          argu_tag[j].append("O")
          argu_tag[j].append("O")
          argu_tag[j].append(train_df.token_tag.iloc[j][i])
          temp_i += 5
        elif train_df.token.iloc[j][i] == argu_token[j][0][temp_i - 1]:
          argu_tag[j][temp_i - 1] = train_df.token_tag.iloc[j][i]
        else:
          argu_tag[j].append("O")
          print("처음", j, i, temp_i)
          print(train_df.token.iloc[j][i], " ", argu_token[j][0][temp_i])
          temp_i += 1
    except:
      if temp_i < len( argu_token[j][0]):
        argu_tag[j].append("O")
        temp_i += 1
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 처음 301 2754 3074
# continued   during
# 처음 301 2755 3075
# increased   hd
# 처음 301 2756 3076
# oxygen   and
# 처음 301 2757 3077
# requirement   the
# 처음 301 2758 3078
# and   patient
# 처음 301 2759 3079
# sob,   was
# 처음 301 2760 3080
# with   given
# 처음 301 2761 3081
# evidence   her
# 처음 301 2762 3082
# of   am
# 처음 301 2763 3083
# pulmonary   bp
# 처음 301 2764 3084
# edema   meds
# 처음 301 2765 3085
# on   as
# 처음 301 2766 3086
# cxr.   a
# 처음 301 2767 3087
# in   result.
# 처음 301 2768 3088
# conjunction   cxr
# 처음 301 2769 3089
# with   indicated
# 처음 301 2770 3090
# the   volume
# 처음 301 2771 3091
# renal   overload
# 처음 301 2772 3092
# team,   and
# 처음 301 2773 3093
# the   pt.
# 처음 301 2774 3094
# patient   was
# 처음 301 2775 3095
# required   thought
# 처음 301 2776 3096
# almost   to
# 처음 301 2777 3097
# daily   have
# 처음 301 2778 3098
# hd   had
# 처음 301 2779 3099
# or   acute
# 처음 301 2780 3100
# ultrafiltration   pulmonary
# ...

# %%
err_list = []

# %%
for i in range(len(argu_tag)):
  if len(argu_token[i][0]) != len(argu_tag[i]):
    err_list.append(i)

# %%
over_tag = []
loss_tag = []

# %%
for i in err_list:
  if len(argu_token[i][0]) > len(argu_tag[i]):
    loss_tag.append(i)
  else:
    over_tag.append(i)

# %%
len(over_tag)
# Out:
# 0

# %%
len(loss_tag)
# Out:
# 92

# %%
j = loss_tag[1]

# %%
argu_tag[j] = []

# %%
temp_i = 0

# %%
for i in range(len(train_df.token.iloc[j])):
    try:
      if train_df.token.iloc[j][i] == argu_token[j][0][temp_i]:
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        temp_i += 1
      elif train_df.token.iloc[j][i] == (argu_token[j][0][temp_i] + argu_token[j][0][temp_i + 1]):
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        temp_i += 2
      elif train_df.token.iloc[j][i] == (argu_token[j][0][temp_i] + argu_token[j][0][temp_i + 1] + argu_token[j][0][temp_i + 2]):
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        temp_i += 3
      elif train_df.token.iloc[j][i] == (argu_token[j][0][temp_i] + argu_token[j][0][temp_i + 1] + argu_token[j][0][temp_i + 2] + argu_token[j][0][temp_i + 3]):
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        temp_i += 4
      elif train_df.token.iloc[j][i] == (argu_token[j][0][temp_i] + argu_token[j][0][temp_i + 1] + argu_token[j][0][temp_i + 2] + argu_token[j][0][temp_i + 3] + argu_token[j][0][temp_i + 4]):
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        temp_i += 5
      elif train_df.token.iloc[j][i] == (argu_token[j][0][temp_i] + argu_token[j][0][temp_i + 1] + argu_token[j][0][temp_i + 2] + argu_token[j][0][temp_i + 3] + argu_token[j][0][temp_i + 4] + argu_token[j][0][temp_i + 5]):
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        temp_i += 6
      elif train_df.token.iloc[j][i] == (argu_token[j][0][temp_i] + argu_token[j][0][temp_i + 1] + argu_token[j][0][temp_i + 2] + argu_token[j][0][temp_i + 3] + argu_token[j][0][temp_i + 4]  + argu_token[j][0][temp_i + 5] + argu_token[j][0][temp_i + 6]):
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        temp_i += 7
      elif train_df.token.iloc[j][i] == (argu_token[j][0][temp_i] + argu_token[j][0][temp_i + 1] + argu_token[j][0][temp_i + 2] + argu_token[j][0][temp_i + 3] + argu_token[j][0][temp_i + 4]  + argu_token[j][0][temp_i + 5] + argu_token[j][0][temp_i + 6] + argu_token[j][0][temp_i + 7]):
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        temp_i += 8
      elif train_df.token.iloc[j][i] == (argu_token[j][0][temp_i] + argu_token[j][0][temp_i + 1] + argu_token[j][0][temp_i + 2] + argu_token[j][0][temp_i + 3] + argu_token[j][0][temp_i + 4]  + argu_token[j][0][temp_i + 5] + argu_token[j][0][temp_i + 6] + argu_token[j][0][temp_i + 7] + argu_token[j][0][temp_i + 8]):
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        temp_i += 9
      elif train_df.token.iloc[j][i] == (argu_token[j][0][temp_i] + argu_token[j][0][temp_i + 1] + argu_token[j][0][temp_i + 2] + argu_token[j][0][temp_i + 3] + argu_token[j][0][temp_i + 4]  + argu_token[j][0][temp_i + 5] + argu_token[j][0][temp_i + 6] + argu_token[j][0][temp_i + 7] + argu_token[j][0][temp_i + 8] + argu_token[j][0][temp_i + 9]):
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        argu_tag[j].append(train_df.token_tag.iloc[j][i])
        temp_i += 10
      else:
        if (train_df.token.iloc[j][i] + train_df.token.iloc[j][i+1]) == argu_token[j][0][temp_i]:
          continue

        if train_df.token.iloc[j][i] == argu_token[j][0][temp_i+1]:
          argu_tag[j].append("O")
          argu_tag[j].append(train_df.token_tag.iloc[j][i])
          temp_i += 2
        elif train_df.token.iloc[j][i] == argu_token[j][0][temp_i + 2]:
          argu_tag[j].append("O")
          argu_tag[j].append("O")
          argu_tag[j].append(train_df.token_tag.iloc[j][i])
          temp_i += 3
        elif train_df.token.iloc[j][i] == argu_token[j][0][temp_i + 3]:
          argu_tag[j].append("O")
          argu_tag[j].append("O")
          argu_tag[j].append("O")
          argu_tag[j].append(train_df.token_tag.iloc[j][i])
          temp_i += 4
        elif train_df.token.iloc[j][i] == argu_token[j][0][temp_i + 4]:
          argu_tag[j].append("O")
          argu_tag[j].append("O")
          argu_tag[j].append("O")
          argu_tag[j].append("O")
          argu_tag[j].append(train_df.token_tag.iloc[j][i])
          temp_i += 5
        elif train_df.token.iloc[j][i] == argu_token[j][0][temp_i - 1]:
          argu_tag[j][temp_i - 1] = train_df.token_tag.iloc[j][i]
        else:
          argu_tag[j].append("O")
          print("처음", j, i, temp_i)
          print(train_df.token.iloc[j][i], " ", argu_token[j][0][temp_i])
          temp_i += 1
    except:
      if temp_i < len( argu_token[j][0]):
        argu_tag[j].append("O")
        temp_i += 1
# Out:
# 처음 7 274 302
# naloxone   naloxone.
# 처음 7 275 303
# .4mg   4mg
# 처음 7 503 551
# .   in.
# 처음 7 839 1267
# =================================   =
# 처음 7 840 1268
# microbiology:   =
# 처음 7 841 1269
# urine   =
# 처음 7 842 1270
# culture   =
# 처음 7 843 1271
# -   =
# 처음 7 844 1272
# no   =
# 처음 7 845 1273
# growth   =
# 처음 7 846 1274
# blood   =
# 처음 7 847 1275
# culture   =
# 처음 7 848 1276
# x   =
# 처음 7 849 1277
# 2   =
# 처음 7 850 1278
# -   =
# 처음 7 851 1279
# no   =
# 처음 7 852 1280
# growth   =
# 처음 7 853 1281
# to   =
# 처음 7 854 1282
# date   =
# 처음 7 855 1283
# (final   =
# 처음 7 856 1284
# report   =
# 처음 7 857 1285
# pending)   =
# 처음 7 858 1286
# =================================   =
# 처음 7 859 1287
# imaging:   =
# 처음 7 860 1288
# cxr   =
# 처음 7 861 1289
# ()   =
# 처음 7 862 1290
# -   =
# 처음 7 863 1291
# findings:   =
# 처음 7 864 1292
# as   =
# 처음 7 865 1293
# compared   =
# 처음 7 866 1294
# to   =
# 처음 7 867 1295
# the   =
# 처음 7 868 1296
# previous   =
# 처음 7 869 1297
# ...

# %%
len(a)
# Out:
# 57

# %%
argu_token[j][0][1060:1140]

# %%
len(train_df.token.iloc[j][734])
# Out:
# 57
